# %%
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]

# %%
desolve_system(syst, [x,y])
# Out:
# [x(t) == 1/2*(2*C2 + x(0))*e^(3*t) - 1/2*(2*C2 - x(0))*e^(-t),
#  y(t) == 1/4*(2*C2 + x(0))*e^(3*t) + 1/4*(2*C2 - x(0))*e^(-t)]

# %%
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %%
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t)

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)

# %%
plot([sol_x(t,1,1),sol_y(t,5,5)],t,-4,4)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==2*x-y
deq2=diff(y,t)==x-2*y
syst=[deq1,deq2]

# %%
desolve_system(syst, [x,y])
# Out:
# [x(t) == -1/3*sqrt(3)*(C2 - 2*x(0))*sinh(sqrt(3)*t) + cosh(sqrt(3)*t)*x(0),
#  y(t) == -1/3*sqrt(3)*(2*C2 - x(0))*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t)]

# %%
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
# Out:
# [x(t) == 1/3*sqrt(3)*(2*C1 - C2)*sinh(sqrt(3)*t) + C1*cosh(sqrt(3)*t),
#  y(t) == 1/3*sqrt(3)*(C1 - 2*C2)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t)]

# %%
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/3*sqrt(3)*(2*C1 - C2)*sinh(sqrt(3)*t) + C1*cosh(sqrt(3)*t)

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> 1/3*sqrt(3)*(C1 - 2*C2)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t)

# %%
plot([sol_x(t,1,1),sol_y(t,5,5)],t,-4,4)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==x-y+z
deq2=diff(y,t)==x+y-z
deq3=diff(y,t)==-y+2*z
syst=[deq1,deq2,deq3]

# %%
desolve_system(syst, [x,y,z])
# Out:
# [x(t) == (C2 - x(0))*e^(2/3*t) - (C2 - 2*x(0))*e^t,
#  y(t) == 2*(C2 - x(0))*e^(2/3*t) - (C2 - 2*x(0))*e^t,
#  z(t) == 5/3*(C2 - x(0))*e^(2/3*t) - (C2 - 2*x(0))*e^t]

# %%
C1,C2,C3=var('C1,C2,C3')
desolve_system(syst, [x,y,z],[0,C1,C2,C3])
# Out:
# [x(t) == -(C1 - C2)*e^(2/3*t) + (2*C1 - C2)*e^t,
#  y(t) == -2*(C1 - C2)*e^(2/3*t) + (2*C1 - C2)*e^t,
#  z(t) == -5/3*(C1 - C2)*e^(2/3*t) + (2*C1 - C2)*e^t]

# %%
sol=desolve_system(syst, [x,y,z],[0,C1,C2,C3])
sol_x(t,C1,C2,C3)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2, C3) |--> -(C1 - C2)*e^(2/3*t) + (2*C1 - C2)*e^t

# %%
sol_y(t,C1,C2,C3)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2, C3) |--> -2*(C1 - C2)*e^(2/3*t) + (2*C1 - C2)*e^t

# %%
sol_z(t,C1,C2,C3)=sol[2].rhs()
sol_z
# Out:
# (t, C1, C2, C3) |--> -5/3*(C1 - C2)*e^(2/3*t) + (2*C1 - C2)*e^t

# %%
plot([sol_x(t,1,1,1),sol_y(t,2,2,1), sol_z(t,3,1,1)],t,-4,4)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==5*x+3*y+1
deq2=diff(y,t)==-6*x-4*y+e^(-t)
syst=[deq1,deq2]

# %%
desolve_system(syst, [x,y])
# Out:
# [x(t) == 1/3*(3*C2 + 6*x(0) + 4)*e^(2*t) - 1/3*(3*C2 + 3*x(0) - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(3*C2 + 6*x(0) + 4)*e^(2*t) + 1/3*(6*C2 + 6*x(0) - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %%
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
# Out:
# [x(t) == 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %%
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3

# %%
plot([sol_x(t,1,1),sol_y(t,7,5)],t,-4,4, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,1,2]

# %%
sol=desolve_system(syst, vars,in_cond)
sol
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> 5/2*e^(3*t) - 3/2*e^(-t)

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> 5/4*e^(3*t) + 3/4*e^(-t)

# %%
plot([sol_x(t), sol_y(t)],t,-4,4, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x-y+t
deq2=diff(y,t)==-2*x+4*y+cos(t)
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]

# %%
sol=desolve_system(syst, vars,in_cond)
sol
# Out:
# [x(t) == -1/221*(274*sqrt(17)*sinh(1/2*sqrt(17)*t) - 1003*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 9/2,
#  y(t) == -1/442*(181*sqrt(17)*sinh(1/2*sqrt(17)*t) - 1649*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 5/2]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> -1/221*(274*sqrt(17)*sinh(1/2*sqrt(17)*t) - 1003*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 9/2

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> -1/442*(181*sqrt(17)*sinh(1/2*sqrt(17)*t) - 1649*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 5/2

# %%
plot([sol_x(t), sol_y(t)],t,-4,4, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+2*y+e^(-t)
deq2=diff(y,t)==2*x+y+1
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]

# %%
sol=desolve_system(syst, vars,in_cond)
sol
# Out:
# [x(t) == 1/2*t*e^(-t) + 19/24*e^(3*t) - 1/8*e^(-t) - 2/3,
#  y(t) == -1/2*t*e^(-t) + 19/24*e^(3*t) - 1/8*e^(-t) + 1/3]

# %%
sol_x(t)=sol[0].rhs()
sol_x
# Out:
# t |--> 1/2*t*e^(-t) + 19/24*e^(3*t) - 1/8*e^(-t) - 2/3

# %%
sol_y(t)=sol[1].rhs()
sol_y
# Out:
# t |--> -1/2*t*e^(-t) + 19/24*e^(3*t) - 1/8*e^(-t) + 1/3

# %%
plot([sol_x(t), sol_y(t)],t,-4,4, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
reset()
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==y
deq2=diff(y,t)==-x-2*y
syst=[deq1,deq2]

# %%
desolve_system(syst, [x,y])
# Out:
# [x(t) == t*e^(-t)*x(0) + t*e^(-t) + e^(-t)*x(0),
#  y(t) == -t*e^(-t)*x(0) - t*e^(-t) + e^(-t)]

# %%
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
# Out:
# [x(t) == C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t),
#  y(t) == -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)]

# %%
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t)

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)

# %%
plot([sol_x(t,1,1),sol_y(t,5,5)],t,-4,4, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
limit(sol_x(t,1,1),t=infinity)
# Out:
# 0

# %%
limit(sol_x(t,1,1),t=infinity)
# Out:
# 0

# %%
f1(u,v)=v
f2(u,v)=-u-2*v

# %%
plot_vector_field( [f1(u,v),f2(u,v)], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u,v)=2*u+v
f2(u,v)=-u+2*v

# %%
plot_vector_field( [f1(u,v),f2(u,v)], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u,v)=v
f2(u,v)=-u

# %%
plot_vector_field( [f1(u,v),f2(u,v)], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u,v)=-u-v
f2(u,v)=u-v

# %%
plot_vector_field( [f1(u,v),f2(u,v)], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u,v)=-2*u
f2(u,v)=-4*u-2*v

# %%
plot_vector_field( [f1(u,v),f2(u,v)], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive
