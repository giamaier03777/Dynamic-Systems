# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) == 2*x*y
desolve(eqd, y)
# Out:
# _C*e^(x^2)

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol.substitute(_C==1)
# Out:
# x

# %%
sol1=sol.substitute(_C==1)

# %%
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) == y/x
desolve(eqd, y)
# Out:
# _C*x

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol.substitute(_C==1)
sol1=sol.substitute(_C==1)
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) == 2*x*(1+y^2)
desolve(eqd, y)
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
sol=desolve(eqd,y)
sol
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
yy=var('yy')
soll= 1/2*arctan(yy) == 1/2*x^2 + _C

# %%
_C=var('_C')
f(x,yy,_C)=soll
f(x,yy,_C)
# Out:
# 1/2*arctan(yy) == 1/2*x^2 + _C

# %%
implicit_plot(f(x,yy,0),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==(2 * x * y^2)/ (x^2 - 1)
desolve(eqd,y)
# Out:
# -1/2/y(x) == _C + 1/2*log(x + 1) + 1/2*log(x - 1)

# %%
sol=desolve(eqd,y)
sol
# Out:
# -1/2/y(x) == _C + 1/2*log(x + 1) + 1/2*log(x - 1)

# %%
yy=var('yy')
soll= -1/2/yy == _C + 1/2*log(x + 1) + 1/2*log(x - 1)

# %%
_C=var('_C')
f(x,yy,_C)=soll
f(x,yy,_C)
# Out:
# -1/2/yy == _C + 1/2*log(x + 1) + 1/2*log(x - 1)

# %%
implicit_plot(f(x,yy,0),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)== 1/cos(x) - (y* tan(x))
desolve(eqd,y)
# Out:
# (_C + tan(x))/sec(x)

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol.substitute(_C==1)
# Out:
# (tan(x) + 1)/sec(x)

# %%
sol1=sol.substitute(_C==1)

# %%
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)== x^3 - 2/3*x
desolve(eqd,y)
# Out:
# 1/4*x^4 - 1/3*x^2 + _C

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol.substitute(_C==1)
# Out:
# 1/4*x^4 - 1/3*x^2 + 1

# %%
sol1=sol.substitute(_C==1)

# %%
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)== 3*x - y/x 
desolve(eqd,y)
# Out:
# (x^3 + _C)/x

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol.substitute(_C==1)
# Out:
# (x^3 + 1)/x

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol.substitute(_C==1)
# Out:
# (x^3 + 1)/x

# %%
sol1=sol.substitute(_C==1)
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1 + y^2
desolve(eqd,y,ics=[0,1])
# Out:
# arctan(y(x)) == 1/4*pi + x

# %%
sol=desolve(eqd,y,ics=[0,1])
sol
# Out:
# arctan(y(x)) == 1/4*pi + x

# %%
yy=var('yy')
soll = arctan(yy) == 1/4*pi + x
soll
# Out:
# arctan(yy) == 1/4*pi + x

# %%
_C=var('_C')
f(x,yy,_C)=soll
f(x,yy,_C)
# Out:
# arctan(yy) == 1/4*pi + x

# %%
implicit_plot(f(x,yy,0),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1/ cos(x) - y*tan(x)
desolve(eqd,y,ics=[0,0])
# Out:
# tan(x)/sec(x)

# %%
sol=desolve(eqd,y)
_C=var('_C')
sol.substitute(_C==1)
# Out:
# (tan(x) + 1)/sec(x)

# %%
sol1=sol.substitute(_C==1)

# %%
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) == 2*x*(1+y^2)
desolve(eqd, y)
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
sol=desolve(eqd,y)
sol1 = solve(sol, y)
sol1
# Out:
# [y(x) == tan(x^2 + 2*_C)]

# %%
sol2 = sol1[0].rhs()
sol2
# Out:
# tan(x^2 + 2*_C)

# %%
_C = var('_C')
sol3 = sol2.substitute(_C == 1)

# %%
plot(sol3, x, -2, 2, ymin = -10, ymax = 10)
# Out:
# Graphics object consisting of 1 graphics primitive
